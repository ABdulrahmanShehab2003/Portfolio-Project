# %% [markdown]
# # Netflix Dataset
#
# ## Big- Data Analysis with Python

# %%
from IPython.display import Image
Image("netflix.png")

# %% [markdown]
# ### This Netflix Dataset has infromation about the TV Shows and Movies available on Netflix till 2021

# %% [markdown]
# ### import libraryes

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# ### importing the dataset

# %%
df = pd.read_csv("NetflixDataset.csv")
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ### Inspecting Datasets

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   object
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: object(11)
# memory usage: 730.0+ KB

# %%
df['Release_Date'] =pd.to_datetime(df['Release_Date'])

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df[df['Director'].isnull()]
# Out:
#      Show_Id Category                                Title Director  \
# 0         s1  TV Show                                   3%      NaN
# 11       s12  TV Show                                 1983      NaN
# 16       s17  TV Show                               Feb-09      NaN
# 19       s20    Movie                                  '89      NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac      NaN
# ...      ...      ...                                  ...      ...
# 7777   s7776  TV Show                           Zoids Wild      NaN
# 7779   s7778  TV Show                          Zombie Dumb      NaN
# 7781   s7780  TV Show                            Zona Rosa      NaN
# 7786   s7785    Movie                    Zulu Man in Japan      NaN
# 7787   s7786  TV Show                Zumbo's Just Desserts      NaN
#
#                                                    Cast  \
# 0     João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df[df['Cast'].isnull()]
# Out:
#      Show_Id Category                                    Title  \
# 12       s13  TV Show                                     1994
# 25       s26    Movie                                 (T)ERROR
# 26       s27  TV Show                                 (Un)Well
# 30       s31    Movie                         #cats_the_mewvie
# 35       s36    Movie                                #Rucker50
# ...      ...      ...                                      ...
# 7681   s7680    Movie          WWII: Report from the Aleutians
# 7688   s7687    Movie                   XV: Beyond the Tryline
# 7768   s7767  TV Show                             Zig & Sharko
# 7779   s7778  TV Show                              Zombie Dumb
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                                     Director Cast  \
# 12                      Diego Enrique Osorno  NaN
# 25    Lyric R. Cabral, David Felix Sutcliffe  NaN
# 26                                       NaN  NaN
# ...

# %%
df[df['Country'].isnull()]
# Out:
#      Show_Id Category                                              Title  \
# 16       s17  TV Show                                             Feb-09
# 38       s39  TV Show                                แผนร้ายนายเจ้าเล่ห์
# 67       s68    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 97       s98    Movie                                        3 Deewarein
# 117     s118    Movie                                     5 Cowok Jagoan
# ...      ...      ...                                                ...
# 7741   s7740    Movie                                    Your Excellency
# 7748   s7747  TV Show                                       دفعة القاهرة
# 7767   s7766    Movie                                          Zero Hour
# 7779   s7778  TV Show                                        Zombie Dumb
# 7786   s7785    Movie                                  Zulu Man in Japan
#
#               Director                                               Cast  \
# ...

# %%
sns.heatmap(data=df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Q.1. for 'House of Cards' ,what is the show id and who is the Director of the show

# %%
df[df['Title']=='House of Cards']
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832   2018-11-02  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q.2. in which year highest number of the TV show & Movies were released ? show with the Bar Graph

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7787 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7787 non-null   object
#  1   Category      7787 non-null   object
#  2   Title         7787 non-null   object
#  3   Director      5399 non-null   object
#  4   Cast          7069 non-null   object
#  5   Country       7280 non-null   object
#  6   Release_Date  7777 non-null   datetime64[ns]
#  7   Rating        7780 non-null   object
#  8   Duration      7787 non-null   object
#  9   Type          7787 non-null   object
#  10  Description   7787 non-null   object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 730.0+ KB

# %%
df['Release_Date'].count()
# Out:
# 7777

# %%
df[df['Release_Date']=='January 1, 2020']
# Out:
#      Show_Id Category                                              Title  \
# 4         s5    Movie                                                 21
# 163     s164    Movie                                 A Cinderella Story
# 433     s434    Movie  Alpha and Omega: The Legend of the Saw Tooth Cave
# 455     s456    Movie                                    American Beauty
# 588     s589    Movie                                   Arthur Christmas
# ...      ...      ...                                                ...
# 7560   s7559    Movie                                  What Lies Beneath
# 7625   s7624    Movie                                     Wild Wild West
# 7630   s7629    Movie                Willy Wonka & the Chocolate Factory
# 7683   s7682    Movie                                         Wyatt Earp
# 7707   s7706    Movie                                            Yes Man
#
#               Director                                               Cast  \
# ...

# %%
df['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
df['Release_Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### Q.3.How mny Movies &TV show are in the dataset ? show with countplot graph

# %%
df.groupby(['Category']).nunique()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5377   5377      3909  4780      590          1350      14
# TV Show      2410   2410       178  2082      183           885       9
#
#           Duration  Type  Description
# Category
# Movie          201   265         5363
# TV Show         15   227         2408

# %%
df['Category'].value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ### َQ.4. show all the moive that were released in year 2000

# %%
df['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
df[df['Release_Date']=='2000']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
df[df['Release_Date']=='2020']
# Out:
#      Show_Id Category                                              Title  \
# 4         s5    Movie                                                 21
# 163     s164    Movie                                 A Cinderella Story
# 433     s434    Movie  Alpha and Omega: The Legend of the Saw Tooth Cave
# 455     s456    Movie                                    American Beauty
# 588     s589    Movie                                   Arthur Christmas
# ...      ...      ...                                                ...
# 7560   s7559    Movie                                  What Lies Beneath
# 7625   s7624    Movie                                     Wild Wild West
# 7630   s7629    Movie                Willy Wonka & the Chocolate Factory
# 7683   s7682    Movie                                         Wyatt Earp
# 7707   s7706    Movie                                            Yes Man
#
#               Director                                               Cast  \
# ...

# %%
df['Year'] = df['Release_Date'].dt.year

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %% [markdown]
# ### Q.5. show only the Titles of all TV show that released in India only

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
df[(df['Category'] == 'TV Show') & (df['Country'] == 'India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# ### Q.6. show top 10 Directors , who gave the number of TV show & Moives to Netfilx

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ### show all the records , where "category is Moive and type is Comedies " or " Country is United Kingdom

# %%
df[ (df['Type'] == 'Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
df[(df['Type'] == 'Comedies') & (df['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                                              Title  \
# 1368   s1369    Movie                                 Christmas Survival
# 1650   s1651    Movie                Dead in a Week (Or Your Money Back)
# 2225   s2226    Movie                                  For Love or Money
# 4210   s4211    Movie   Monty Python Live (Mostly): One Down, Five to Go
# 4213   s4214    Movie           Monty Python: Live at The Hollywood Bowl
# 4781   s4782    Movie  Parrot Sketch Not Included: Twenty Years of Mo...
# 4792   s4793    Movie                                     PATRICK (2019)
# 6109   s6109    Movie                            The Bad Education Movie
# 6947   s6946    Movie                                  The Trip to Spain
#
#                            Director  \
# 1368                  James Dearden
# 1650                    Tom Edmunds
# 2225                    Mark Murphy
# 4210                      Eric Idle
# 4213  Terry Hughes, Ian MacNaughton
# ...

# %% [markdown]
# ### Q.8. how many moives & tv shows , Tom Cruise was cast

# %%
df[(df['Cast'] == 'Tom Cruise')]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Year]
# Index: []

# %%
New_df = df.dropna()

# %%
New_df[New_df['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# ### Q.9. what are the different ratings by Netfilx ?

# %%
df['Rating'].value_counts()
# Out:
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: Rating, dtype: int64

# %% [markdown]
# ### Q.9.1 How many Moives got the "TV-14" rating in Canda?

# %%
df[(df['Category']=='Movie')&(df['Rating'] == 'TV-14') & (df['Country'] == 'Canada')]
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 3713   s3714    Movie                            Long Time Running
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# 5336   s5336    Movie                   Sadie's Last Days on Earth
# 5393   s5393    Movie                                   Sardaar ji
# 6062   s6062    Movie                  The Accountant of Auschwitz
# 7025   s7024    Movie                         The Wrong Babysitter
# 7041   s7040    Movie               There's Something in the Water
#
#                                     Director  \
# 30                          Michael Margolis
# 34                           Michael Kennedy
# ...

# %% [markdown]
# ### Q.9.2 how many TV show got the rate "R" ,after year 2018 ?

# %%
df[(df['Category']=='TV Show')&(df['Rating'] == 'R') & (df['Year'] > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %% [markdown]
# ### Q.10 what is the maximum duration of a Movie & TV show on netflix

# %%
df['Duration'].value_counts()
# Out:
# 1 Season     1608
# 2 Seasons     382
# 3 Seasons     184
# 90 min        136
# 93 min        131
#              ...
# 182 min         1
# 224 min         1
# 233 min         1
# 196 min         1
# 191 min         1
# Name: Duration, Length: 216, dtype: int64

# %% [markdown]
# ### Q.11 which individual country has the Highest No. of TV show

# %%
df_tvshow = df[df['Category'] == 'TV Show']

# %%
df_tvshow['Country'].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %%
df_tvshow['Country'].value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ### Q.12 How can sort the dataset by Year

# %%
df.sort_values(by='Year', ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...
